# %% [markdown]
# <a href="https://colab.research.google.com/github/HinguDhwani/Books/blob/main/Proj_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 25.91 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 8.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 11.0 MB/s
# ...
#      |████████████████████████████████| 8.3 MB 53.2 MB/s
# ...
#      |████████████████████████████████| 547 kB 62.5 MB/s
# ...
#      |████████████████████████████████| 138 kB 67.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Toy Television Couch Blender Bicycle Laptop Handbag Headphones --type_csv train --multiclasses 1 --limit 100
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Toy', 'Television', 'Couch', 'Blender', 'Bicycle', 'Laptop', 'Handbag', 'Headphones'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 42907 KB/s, 0 seconds passed
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
data_folder = os.path.join(os.getcwd(), '/content/OID/Dataset/train/Toy_Television_Couch_Blender_Bicycle_Laptop_Handbag_Headphones/Label')

# %%
list(os.walk(data_folder))
# Out:
# [('/content/OID/Dataset/train/Toy_Television_Couch_Blender_Bicycle_Laptop_Handbag_Headphones/Label',
#   [],
#   ['e1316b8ebf7afdcd.txt',
#    '5fecba231df25b91.txt',
#    '0c58ec4af962f275.txt',
#    '0d4688895f2d54c4.txt',
#    'c5b1d8f80875bdc7.txt',
#    'becae8f378af8e13.txt',
#    '0e12cdddea15d792.txt',
#    'd597ff96c809fb66.txt',
#    '4f815f20a3f635d7.txt',
#    'b2f8f56f53c510c7.txt',
#    'f45a311c3b551d0a.txt',
#    '00abbb60a03945ee.txt',
#    '9d6938f8da4831f6.txt',
#    '8368761a05cce3e5.txt',
#    'c962641e2a255a11.txt',
#    'd9be5d9e7453832f.txt',
#    '46572cc9c0218100.txt',
#    '2abbb010297b68b4.txt',
#    'd879dfd5322c8339.txt',
#    'e09c78833c53526e.txt',
#    'b1f7636758497f17.txt',
#    'f5f6666a208dc931.txt',
#    '925e8a481a7efd70.txt',
#    '3542a108d8649f64.txt',
#    '5577ce7b4e692588.txt',
#    '0858a130f1db0fe7.txt',
#    '29043dc3ee5eccc8.txt',
#    '8f1c523274bb80ae.txt',
#    '0cf74b679b7221af.txt',
#    'c2d82a660614cf90.txt',
# ...

# %%
len(data_folder)
# Out:
# 95

# %%
data = []
for root, folders, files in os.walk(data_folder):
  for file in files:
    path = os.path.join(root,file)
    with open(path) as inf:
      data.append(inf.read().split())

# %%
data
# Out:
# [['Bicycle',
#   '0.0',
#   '361.599744',
#   '241.92',
#   '479.36025600000005',
#   'Bicycle',
#   '341.12',
#   '394.88025600000003',
#   '385.28',
#   '419.840256',
#   'Bicycle',
#   '363.52',
#   '462.08025599999996',
#   '504.96',
#   '641.28',
#   'Bicycle',
#   '392.96',
#   '399.99974399999996',
#   '437.76',
#   '417.27974399999994',
#   'Bicycle',
#   '497.28',
#   '390.39974400000006',
#   '556.8',
#   '419.840256',
#   'Bicycle',
#   '538.24',
#   '410.24025600000004',
#   '869.12',
#   '641.919744'],
#  ['Bicycle',
#   '577.92',
#   '284.47633',
#   '687.36',
#   '555.498243',
#   'Bicycle',
#   '47.36',
#   '271.66256699999997',
#   '161.92',
#   '535.6359199999999',
#   'Bicycle',
#   '105.6',
#   '427.996486',
#   '309.76',
#   '682.3593460000001',
#   'Bicycle',
#   '977.92',
#   '220.405466',
#   '1023.36',
#   '296.650122'],
#  ['Bicycle', '176.64', '534.4', '989.44', '976.0'],
#  ['Bicycle',
#   '96.0',
#   '366.399744',
#   '166.4',
#   '451.20000000000005',
# ...

# %%
import pandas as pd

df = pd.DataFrame(data,columns=['Label','x','y','w','h'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     563     try:
# --> 564         columns = _validate_or_indexify_columns(content, columns)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     688             raise AssertionError(
# --> 689                 f"{len(columns)} columns passed, passed data had "
#     690                 f"{len(content)} columns"
#
# AssertionError: 5 columns passed, passed data had 65 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
type(data)
# Out:
# list

# %%
type(data_folder)
# Out:
# str

# %% [markdown]
# Reading Text Files words into list

# %%
f = open("/content/OID/Dataset/train/Bicycle/Label/00f1cfe890a86000.txt", "r")

# %% [markdown]
# #Reading all content of text file

# %% [markdown]
# using the split( function)

# %%
a = f.read().split()
print(a)
# Out:
# ['Bicycle', '27.52', '303.82349800000003', '1023.36', '681.35892']

# %%
type(a)
# Out:
# list
